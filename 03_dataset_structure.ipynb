# %% [markdown]
# <a href="https://colab.research.google.com/github/porquenogr/precision-livestock-ai/blob/main/03_dataset_structure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pathlib import Path
base_dir = Path('dataset')
for split in ['train', 'val']:
    (base_dir / 'images' / split).mkdir(parents=True, exist_ok=True)
    (base_dir / 'labels' / split).mkdir(parents=True, exist_ok=True)
print("[INFO] Dataset architecture initialized successfully:")
for path in sorted(base_dir.glob('**/*')):
    if path.is_dir():
        print(f"  ├── folder: {path}")

print("\n[READY] Environment is configured for custom pig detection pipeline.")
# Out:
# [INFO] Dataset architecture initialized successfully:
#   ├── folder: dataset/images
#   ├── folder: dataset/images/train
#   ├── folder: dataset/images/val
#   ├── folder: dataset/labels
#   ├── folder: dataset/labels/train
#   ├── folder: dataset/labels/val
#
# [READY] Environment is configured for custom pig detection pipeline.
